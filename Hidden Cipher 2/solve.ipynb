# %%
pwd = [1568, 1470, 1386, 1554, 938, 1176, 980, 1722, 1526, 728, 1624, 1456, 1330, 1372, 714, 1456, 686, 1540, 1400, 1330, 1386, 686, 1568, 1456, 714, 1596, 1330, 672, 686, 686, 714, 742, 1372, 1414, 742, 1750]
flag = ""
for c in pwd:
    num = c // 14
    flag += chr(num)
print(flag)
# Out:
# picoCTF{m4th_b3h1nd_c1ph3r_01135be5}
