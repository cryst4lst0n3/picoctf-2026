# %%
pwd = '235a201d702015483b1d412b265d3313501f0c072d135f0d2002302d57113700761357102e'
offset = [83, 51, 67, 114, 51, 116]
flag = ""
j = 0
for i in range(0,len(pwd),2):
    c = pwd[i] + pwd[i+1]
    flag += chr(int(c,16) ^  offset[j%6])
    j += 1
print(flag)
# Out:
# picoCTF{xor_unpack_4nalys1s_ded35add}
