# %%
for i in range(1000,9999):
    res = format(i, '04x')
    if res[0] == '0':
        print(res)
# Out:
# 03e8
# 03e9
# 03ea
# 03eb
# 03ec
# 03ed
# 03ee
# 03ef
# 03f0
# 03f1
# 03f2
# 03f3
# 03f4
# 03f5
# 03f6
# 03f7
# 03f8
# 03f9
# 03fa
# 03fb
# 03fc
# 03fd
# 03fe
# 03ff
# 0400
# 0401
# 0402
# 0403
# 0404
# 0405
# 0406
# 0407
# 0408
# 0409
# 040a
# 040b
# 040c
# 040d
# 040e
# 040f
# 0410
# 0411
# 0412
# 0413
# 0414
# 0415
# 0416
# 0417
# 0418
# 0419
# 041a
# 041b
# 041c
# 041d
# 041e
# 041f
# 0420
# 0421
# 0422
# 0423
# 0424
# 0425
# 0426
# 0427
# 0428
# 0429
# 042a
# 042b
# 042c
# 042d
# 042e
# 042f
# 0430
# 0431
# 0432
# 0433
# 0434
# 0435
# 0436
# 0437
# 0438
# 0439
# 043a
# 043b
# 043c
# 043d
# 043e
# 043f
# 0440
# 0441
# 0442
# 0443
# 0444
# 0445
# 0446
# 0447
# 0448
# 0449
# 044a
# 044b
# 044c
# 044d
# 044e
# 044f
# 0450
# 0451
# 0452
# 0453
# 0454
# 0455
# 0456
# 0457
# 0458
# 0459
# 045a
# 045b
# 045c
# 045d
# 045e
# 045f
# 0460
# 0461
# 0462
# 0463
# 0464
# 0465
# 0466
# 0467
# 0468
# 0469
# 046a
# 046b
# 046c
# 046d
# 046e
# 046f
# 0470
# 0471
# 0472
# 0473
# 0474
# 0475
# ...

# %%
pwd = '}adbftc_oc_ipe082ftc_oc_ipf_99ftc_oc_ip9_TGftc_oc_ip_xehftc_oc_ip_tigftc_oc_ipid_3ftc_oc_ip{FTCftc_oc_ipocipftc_oc_ip'
pwd = pwd.replace("ftc_oc_ip", "")
pwd = pwd[:: -1]
print(pwd)
# Out:
# picoCTF{3_digit_hex_GT_999_f280ebda}
